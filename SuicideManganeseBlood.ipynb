# %%
import pandas as pd
import warnings 

# %matplotlib inline
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import scipy.stats as stats
import numpy as np
import seaborn as sns

mag = pd.read_sas("Downloads/PBCD_J.XPT")

print(mag.head())
# Out:
#          SEQN    LBXBPB  LBDBPBSI      LBDBPBLC    LBXBCD  LBDBCDSI  \
# 0  91127.0000       NaN       NaN           NaN       NaN       NaN
# 1  91123.9375       NaN       NaN           NaN  0.067371  0.247060
# 2  91123.9375  2.952900  0.137681  5.397605e-79  0.239994  2.140000
# 3  91123.9375  0.247807  0.015441  5.397605e-79  0.207996  1.827941
# 4  91123.9375  0.387681  0.019836  5.397605e-79  0.137681  1.250000
#
#        LBDBCDLC    LBXTHG   LBDTHGSI      LBDTHGLC     LBXBSE  LBDBSESI  \
# 0           NaN       NaN        NaN           NaN        NaN       NaN
# 1  1.000000e+00  0.469990   2.327941  5.397605e-79  63.278306  1.765441
# 2  5.397605e-79  1.069885   5.339904  5.397605e-79  63.247059  2.327941
# 3  5.397605e-79  3.952500  53.090000  5.397605e-79  63.438465  2.529846
# 4  5.397605e-79  0.200000   1.000000  1.000000e+00  63.340000  2.279846
#
#        LBDBSELC    LBXBMN    LBDBMNSI      LBDBMNLC
# 0           NaN       NaN         NaN           NaN
# 1  5.397605e-79  3.952969   63.278306  5.397605e-79
# 2  5.397605e-79  3.944885   63.247807  5.397605e-79
# 3  5.397605e-79  3.944885  256.077941  5.397605e-79
# 4  5.397605e-79  3.952941   63.348621  5.397605e-79

# %%
depression = pd.read_sas("Downloads/DPQ_J.XPT")
print(depression.head())
# Out:
#       SEQN        DPQ010        DPQ020        DPQ030        DPQ040  \
# 0  93705.0  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 1  93706.0  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 2  93708.0  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 3  93709.0           NaN           NaN           NaN           NaN
# 4  93711.0  1.000000e+00  5.397605e-79  1.000000e+00  5.397605e-79
#
#          DPQ050        DPQ060        DPQ070        DPQ080        DPQ090  \
# 0  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 1  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 2  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 3           NaN           NaN           NaN           NaN           NaN
# 4  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
#
#          DPQ100
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4  5.397605e-79

# %%
data_compare = pd.merge(mag, depression, how = "inner", on = "SEQN")
data_compare.head()
# Out:
#       SEQN    LBXBPB  LBDBPBSI      LBDBPBLC    LBXBCD  LBDBCDSI  \
# 0  94208.0  0.450000  0.019836  5.397605e-79  0.157215  1.390458
# 1  94210.0  4.769836  0.227528  5.397605e-79  0.400000  3.515441
# 2  94211.0  0.407215  0.019836  5.397605e-79  0.188465  1.690000
# 3  94212.0  1.839904  0.090000  5.397605e-79  0.477528  4.269836
# 4  94214.0  0.247059  0.015441  5.397605e-79  0.219990  1.959999
#
#        LBDBCDLC    LBXTHG   LBDTHGSI      LBDTHGLC  ...        DPQ010  \
# 0  5.397605e-79  0.387681   1.950000  5.397605e-79  ...  1.000000e+00
# 1  5.397605e-79  4.250000  21.207996  5.397605e-79  ...  5.397605e-79
# 2  5.397605e-79  0.247500   2.765441  5.397605e-79  ...  5.397605e-79
# 3  5.397605e-79  2.200000   3.952900  5.397605e-79  ...  2.000000e+00
# 4  5.397605e-79  0.340000   1.700000  5.397605e-79  ...  5.397605e-79
#
#          DPQ020        DPQ030        DPQ040        DPQ050        DPQ060  \
# 0  1.000000e+00  2.000000e+00  5.397605e-79  5.397605e-79  3.000000e+00
# 1  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
# 2  1.000000e+00  2.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79
# 3  3.000000e+00  2.000000e+00  3.000000e+00  2.000000e+00  5.397605e-79
# 4  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79  5.397605e-79
#
#          DPQ070        DPQ080        DPQ090        DPQ100
# 0  1.000000e+00  1.000000e+00  5.397605e-79  1.000000e+00
# 1  5.397605e-79  5.397605e-79  5.397605e-79           NaN
# 2  1.000000e+00  5.397605e-79  5.397605e-79  5.397605e-79
# 3  3.000000e+00  3.000000e+00  5.397605e-79  1.000000e+00
# 4  5.397605e-79  5.397605e-79  5.397605e-79           NaN
#
# [5 rows x 26 columns]

# %%
row_count= len(data_compare)
print(row_count)
# Out:
# 2406

# %%
data_compare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2406 entries, 0 to 2405
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      2406 non-null   float64
#  1   LBXBPB    2149 non-null   float64
#  2   LBDBPBSI  2149 non-null   float64
#  3   LBDBPBLC  2149 non-null   float64
#  4   LBXBCD    2228 non-null   float64
#  5   LBDBCDSI  2228 non-null   float64
#  6   LBDBCDLC  2228 non-null   float64
#  7   LBXTHG    2228 non-null   float64
#  8   LBDTHGSI  2228 non-null   float64
#  9   LBDTHGLC  2228 non-null   float64
#  10  LBXBSE    2228 non-null   float64
#  11  LBDBSESI  2228 non-null   float64
#  12  LBDBSELC  2228 non-null   float64
#  13  LBXBMN    2228 non-null   float64
#  14  LBDBMNSI  2228 non-null   float64
#  15  LBDBMNLC  2228 non-null   float64
#  16  DPQ010    2191 non-null   float64
#  17  DPQ020    2190 non-null   float64
#  18  DPQ030    2190 non-null   float64
#  19  DPQ040    2190 non-null   float64
#  20  DPQ050    2190 non-null   float64
#  21  DPQ060    2190 non-null   float64
#  22  DPQ070    2190 non-null   float64
#  23  DPQ080    2190 non-null   float64
#  24  DPQ090    2189 non-null   float64
#  25  DPQ100    1412 non-null   float64
# dtypes: float64(26)
# memory usage: 488.8 KB

# %%
data_frame = pd.DataFrame({"ID": data_compare["SEQN"], 
                           "Lack of Interest": data_compare["DPQ010"],
                           "Feeling Depressed": data_compare["DPQ020"],
                           "Suicidal Ideation": data_compare["DPQ090"],
                           "Affect on Daily Life": data_compare["DPQ100"],
                           "Blood Mercury (ug/L)": data_compare["LBXTHG"],
                           "Blood Manganese (ug/L)": data_compare["LBXBMN"]
                            })
data_frame.head()
# Out:
#         ID  Lack of Interest  Feeling Depressed  Suicidal Ideation  \
# 0  94208.0      1.000000e+00       1.000000e+00       5.397605e-79
# 1  94210.0      5.397605e-79       5.397605e-79       5.397605e-79
# 2  94211.0      5.397605e-79       1.000000e+00       5.397605e-79
# 3  94212.0      2.000000e+00       3.000000e+00       5.397605e-79
# 4  94214.0      5.397605e-79       5.397605e-79       5.397605e-79
#
#    Affect on Daily Life  Blood Mercury (ug/L)  Blood Manganese (ug/L)
# 0          1.000000e+00              0.387681                3.967346
# 1                   NaN              4.250000                3.954894
# 2          5.397605e-79              0.247500                3.944885
# 3          1.000000e+00              2.200000                3.952941
# 4                   NaN              0.340000                3.952969

# %%
data_frame.dropna(inplace =True)
print(data_frame)
# Out:
#             ID  Lack of Interest  Feeling Depressed  Suicidal Ideation  \
# 0      94208.0      1.000000e+00       1.000000e+00       5.397605e-79
# 2      94211.0      5.397605e-79       1.000000e+00       5.397605e-79
# 3      94212.0      2.000000e+00       3.000000e+00       5.397605e-79
# 7      94229.0      5.397605e-79       1.000000e+00       5.397605e-79
# 8      94241.0      5.397605e-79       1.000000e+00       5.397605e-79
# ...        ...               ...                ...                ...
# 2392  102913.0      5.397605e-79       5.397605e-79       5.397605e-79
# 2394  102916.0      5.397605e-79       1.000000e+00       5.397605e-79
# 2397  102929.0      5.397605e-79       5.397605e-79       5.397605e-79
# 2399  102934.0      5.397605e-79       5.397605e-79       5.397605e-79
# 2403  102947.0      5.397605e-79       5.397605e-79       5.397605e-79
#
#       Affect on Daily Life  Blood Mercury (ug/L)  Blood Manganese (ug/L)
# 0             1.000000e+00              0.387681                3.967346
# 2             5.397605e-79              0.247500                3.944885
# 3             1.000000e+00              2.200000                3.952941
# 7             5.397605e-79              0.247500                7.702910
# 8             5.397605e-79              2.952910                3.952941
# ...                    ...                   ...                     ...
# 2392          5.397605e-79              1.259826                3.952949
# 2394          5.397605e-79              0.387681                3.952958
# 2397          5.397605e-79              0.200000                6.140458
# 2399          5.397605e-79              0.200000                7.140000
# 2403          5.397605e-79              1.829894                3.327941
#
# [1315 rows x 7 columns]

# %%
# change the values for the indicators to whole number integers so it is easier to compare
# you can see what the values represent in the data table discription in the links provided
# https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/DPQ_J.htm#DPQ100
data_frame = data_frame.astype({"Feeling Depressed":int,
                                "Lack of Interest": int,
                                "Suicidal Ideation": int,
                                "Affect on Daily Life": int,
                                "Blood Manganese (ug/L)": float,
                                "ID": float,
                                "Blood Mercury (ug/L)": float})
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1315 entries, 0 to 2403
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      1315 non-null   float64
#  1   Lack of Interest        1315 non-null   int32
#  2   Feeling Depressed       1315 non-null   int32
#  3   Suicidal Ideation       1315 non-null   int32
#  4   Affect on Daily Life    1315 non-null   int32
#  5   Blood Mercury (ug/L)    1315 non-null   float64
#  6   Blood Manganese (ug/L)  1315 non-null   float64
# dtypes: float64(3), int32(4)
# memory usage: 61.6 KB

# %%
# acceptable manganese levels in the blood are between 4-15 ug/L according to google
data_frame.boxplot("Blood Manganese (ug/L)", by= "Suicidal Ideation", figsize= (20,20))
# Out:
# <Axes: title={'center': 'Blood Manganese (ug/L)'}, xlabel='Suicidal Ideation'>

# %%
level0 = data_frame[data_frame["Suicidal Ideation"]== 0]["Blood Manganese (ug/L)"]
level1 = data_frame[data_frame["Suicidal Ideation"]== 1]["Blood Manganese (ug/L)"]
level2 = data_frame[data_frame["Suicidal Ideation"]== 2]["Blood Manganese (ug/L)"]
level3 = data_frame[data_frame["Suicidal Ideation"]== 3]["Blood Manganese (ug/L)"]
level9 = data_frame[data_frame["Suicidal Ideation"]== 9]["Blood Manganese (ug/L)"]

# %%
# using ANOVA because we are comparing more than 2 groups
# since the p value is ~0.35 this means that there is no statistical difference between the variables compared
stats.f_oneway(level0, level1, level2, level3)
# Out:
# F_onewayResult(statistic=0.28237447750232203, pvalue=0.8381537984932422)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
 
# Assuming you have your data in a DataFrame called 'data_frame'
# If not, you'll need to load your data first
 
# Calculate the correlation coefficient
correlation = data_frame['Blood Manganese (ug/L)'].corr(data_frame['Suicidal Ideation'])
 
# Perform Spearman correlation test
spearman_corr, p_value = stats.spearmanr(data_frame['Blood Manganese (ug/L)'], data_frame['Suicidal Ideation'])
 
# Create a correlation matrix
corr_matrix = data_frame[['Blood Manganese (ug/L)', 'Suicidal Ideation']].corr()
 
# Set up the matplotlib figure
plt.figure(figsize=(10, 8))
 
# Create a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
 
# Set title
plt.title('Correlation Heatmap: Blood Manganese vs Thoughts of Suicide')
 
# Show the plot
plt.show()
 
# Print Spearman correlation results
print(f"Spearman Correlation Coefficient: {spearman_corr:.4f}")
print(f"P-value: {p_value:.4f}")
 
# Interpret the correlation
def interpret_correlation(coeff):
    if abs(coeff) > 0.7:
        return "Strong"
    elif abs(coeff) > 0.3:
        return "Moderate"
    else:
        return "Weak"
 
print(f"Interpretation: {interpret_correlation(spearman_corr)} {'positive' if spearman_corr > 0 else 'negative'} correlation")
# Out:
# Spearman Correlation Coefficient: -0.0116
# P-value: 0.6733
# Interpretation: Weak negative correlation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
 
# Assuming you have your data in a DataFrame called 'data_frame'
# If not, you'll need to load your data first
# For this example, we'll create a sample DataFrame

 
# Calculate the Pearson correlation coefficient
pearson_corr = data_frame['Blood Manganese (ug/L)'].corr(data_frame['Suicidal Ideation'])
 
# Perform Spearman correlation test
spearman_corr, p_value = stats.spearmanr(data_frame['Blood Manganese (ug/L)'], data_frame['Suicidal Ideation'])
 
# Create a correlation matrix
corr_matrix = data_frame[['Blood Manganese (ug/L)', 'Suicidal Ideation']].corr()
 
# Set up the matplotlib figure
plt.figure(figsize=(10, 8))
 
# Create a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
 
# Set title
plt.title('Correlation Heatmap: Blood Manganese vs Thoughts of Suicide')
 
# Show the plot
plt.show()
 
# Print correlation results
print(f"Pearson Correlation Coefficient: {pearson_corr:.4f}")
print(f"Spearman Correlation Coefficient: {spearman_corr:.4f}")
print(f"P-value: {p_value:.4f}")
 
# Interpret the correlation
def interpret_correlation(coeff):
    if abs(coeff) > 0.7:
        return "Strong"
    elif abs(coeff) > 0.3:
        return "Moderate"
    else:
        return "Weak"
 
print(f"Interpretation: {interpret_correlation(spearman_corr)} {'positive' if spearman_corr > 0 else 'negative'} correlation")
# Out:
# Pearson Correlation Coefficient: 0.0176
# Spearman Correlation Coefficient: -0.0116
# P-value: 0.6733
# Interpretation: Weak negative correlation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
# Assuming you have your data in a DataFrame called 'data_frame'
# If not, you'll need to load your data first
# For this example, we'll create a sample DataFrame

# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(10, 6))
 
# Create the scatter plot with regression line
sns.regplot(x='Blood Manganese (ug/L)', y='Suicidal Ideation', data=data_frame, ax=ax)
 
# Customize the plot
ax.set_title('Blood Manganese Levels vs Suicidal Ideation Frequency', fontsize=16)
ax.set_xlabel('Blood Manganese (ug/L)', fontsize=12)
ax.set_ylabel('Suicidal Ideation Frequency', fontsize=12)
 
# Add a text box with correlation information
correlation = data_frame['Blood Manganese (ug/L)'].corr(data_frame['Suicidal Ideation'])
ax.text(0.05, 0.95, f'Correlation: {correlation:.2f}', transform=ax.transAxes, 
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))
 
# Adjust layout and display the plot
plt.tight_layout()
plt.show()
